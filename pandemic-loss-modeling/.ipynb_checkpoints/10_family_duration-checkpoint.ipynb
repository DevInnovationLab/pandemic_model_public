# %% [markdown]
# # Epidemic Duration by Viral Family

# %% [markdown]
# - **Summary**: This document visualizes the duration of epidemics across families.
#
# - **Data Required:** `epidemics_marani_240816.xlsx`

# %% [markdown]
# - **Author**: Ganqi Li (ganqi.li.25@dartmouth.edu)
# - **Updated**: Sep 16, 2024

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm


from scipy.integrate import quad
from scipy.stats import genpareto
from scipy.optimize import minimize

## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## 0. Prepare viral epidemic data

# %%
## Read epidemic data from Marani et al. 
df = pd.read_excel("data/epidemics_marani_240914_family.xlsx")

# %%
## Subset to epidemics from viral families
df_viral = df[df['family'].notna()].reset_index(drop=True)
df_viral = df_viral[df_viral['family'] != "misc"]

## Subset to epidemics with known severities
df_viral_known = df_viral[df_viral["severity_smu"] > 0].reset_index(drop=True)

## Subset to more recent era (1900-present)
yrmin = 1900
df_viral_known_1900 = df_viral_known[df_viral_known["year_start"] 
                                     >= yrmin].reset_index(drop=True)

# %%
## Print minimum severity to determine lower bound for x-axis
print(f'Minimum severity: {df_viral_known_1900["severity_smu"].min(): .5f} SMU')

## Print maximum severity to determine upper bound for x-axis
print(f'Maximum severity: {df_viral_known_1900["severity_smu"].max(): .5f} SMU')

## Print maximum duration to determine upper bound for y-axis
print(f'Maximum duration: {df_viral_known_1900["duration"].max()} years')
# Out:
# Minimum severity:  0.00016 SMU
# Maximum severity:  170.82154 SMU
# Maximum duration: 51 years

# %%
df_viral_known_1900.head(2)
# Out:
#                                             location  year_start  year_end  \
# 0                                         usa, yukon        1900      1900
# 1  russia, france, england, wales, italy, hungary...        1900      1950
#
#    duration  death_thousand  pop_thousand  severity_perthousand  severity_smu  \
# 0         1             0.1     1633000.0              0.000061      0.000612
# 1        51          1510.0     1633000.0              0.924679      9.246785
#
#      disease   type transmission  is_vira_only  is_vira_mixed  contains_vira  \
# 0  influenza  viral      droplet             1              0              1
# 1   smallpox  viral      droplet             1              0              1
#
#    is_pandemic            family
# 0            0  orthomyxoviridae
# 1            1        poxviridae

# %% [markdown]
# ## 1. Plot duration against log severity

# %%
## Save dataframe to excel file
# df_viral_known_1900.to_excel("data/epidemics_viral_known_1900_240916.xlsx", index=False)

# %%
## Subset to threshold-exceedance durations if applicable
thresh = 0.01
df_viral_known_1900 = df_viral_known_1900[df_viral_known_1900['severity_smu'] 
                                          >= thresh].reset_index(drop=True)

# %%
## Subset to respiratory viruses if applicable
# df_viral_known_1900 = df_viral_known_1900[(df_viral_known_1900['family'] == 'orthomyxoviridae') | 
#                                          (df_viral_known_1900['family'] == 'coronaviridae')].reset_index(drop=True)

# %%
## Set figure size
plt.figure(figsize=(18, 5))

## Plot duration vs severity for epidemics  
plt.scatter(df_viral_known_1900['severity_smu'], 
            df_viral_known_1900['duration'], 
            edgecolor='red', facecolors='none', label="Threshold-exceeding viral epidemics since 1900", s=50)

## Set x-axis scale and limits
# plt.xscale('log')
# plt.xlim(1e-4, 1e3)
# plt.xlim(1e-2, 1e3)

## Set y-axis limits
plt.ylim(0,60)

## Add title and axes labels
# plt.title('Censored  Durations of Threshold-Exceeding Respiratory Epidemics', fontsize = 12)
plt.xlabel('Epidemic severity (SMU = deaths per 10,000 people) (log scale)', fontsize=13)
plt.ylabel('Duration (years)', fontsize = 13)

## Display legend
plt.legend()

plt.show()
# Out:
# (0.0, 60.0)
# Text(0.5, 0, 'Epidemic severity (SMU = deaths per 10,000 people) (log scale)')
# Text(0, 0.5, 'Duration (years)')

# %%
## Set independent variable: natural log of flu severity
# df_viral_known_1900['ln_severity_smu'] = np.log(df_viral_known_1900['severity_smu'])
# X = df_viral_known_1900['ln_severity_smu']

X = df_viral_known_1900['severity_smu']

## Add a constant for the intercept term
X = sm.add_constant(X)

## Set dependent variable: duration
y = df_viral_known_1900['duration']

## Fit OLS
model = sm.OLS(y, X).fit()

## Print regression summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               duration   R-squared:                       0.074
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     1.350
# Date:                Tue, 17 Sep 2024   Prob (F-statistic):              0.261
# Time:                        07:56:19   Log-Likelihood:                -76.365
# No. Observations:                  19   AIC:                             156.7
# Df Residuals:                      17   BIC:                             158.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            5.8682      3.480      1.686      0.110      -1.474      13.210
# severity_smu     0.0903      0.078      1.162      0.261      -0.074       0.254
# ==============================================================================
# Omnibus:                       24.579   Durbin-Watson:                   1.550
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.189
# Skew:                           2.280   Prob(JB):                     6.21e-08
# Kurtosis:                       7.596   Cond. No.                         47.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/lichong/anaconda3/lib/python3.11/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
## One-hot encode the 'family' column
df_family_dummies = pd.get_dummies(df_viral_known_1900['family'], prefix='family', drop_first=True)

## Convert True/False to 1/0
df_family_dummies = df_family_dummies.astype(int)



## Set independent variable: natural log of flu severity
# df_viral_known_1900['ln_severity_smu'] = np.log(df_viral_known_1900['severity_smu'])
# X = df_viral_known_1900['ln_severity_smu']

X = df_viral_known_1900['severity_smu']







## Add a constant for the intercept term
X = sm.add_constant(X)

## Combine the viral family dummies with X
X = pd.concat([X, df_family_dummies], axis=1)




## Set dependent variable: duration
y = df_viral_known_1900['duration']

# df_viral_known_1900['ln_duration'] = np.log(df_viral_known_1900['duration'])
# y = df_viral_known_1900['ln_duration']




## Fit OLS
model = sm.OLS(y, X).fit()

## Print regression summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               duration   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.070
# Method:                 Least Squares   F-statistic:                     1.170
# Date:                Tue, 17 Sep 2024   Prob (F-statistic):              0.400
# Time:                        07:56:19   Log-Likelihood:                -70.813
# No. Observations:                  19   AIC:                             159.6
# Df Residuals:                      10   BIC:                             168.1
# Df Model:                           8
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       5.7708     13.887      0.416      0.687     -25.172      36.714
# severity_smu                0.0250      0.095      0.262      0.799      -0.188       0.238
# family_filoviridae         -1.7712     19.620     -0.090      0.930     -45.488      41.945
# family_flaviviridae        -4.7717     19.620     -0.243      0.813     -48.488      38.945
# family_orthomyxoviridae    -4.9013     15.873     -0.309      0.764     -40.269      30.467
# family_paramyxoviridae     -4.4417     16.027     -0.277      0.787     -40.152      31.269
# family_picornaviridae      -2.4383     16.028     -0.152      0.882     -38.150      33.274
# family_poxviridae           6.3820     15.199      0.420      0.683     -27.483      40.247
# family_retroviridae        35.9001     21.177      1.695      0.121     -11.286      83.086
# ==============================================================================
# Omnibus:                       34.638   Durbin-Watson:                   1.108
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               83.948
# Skew:                           2.775   Prob(JB):                     5.90e-19
# Kurtosis:                      11.674   Cond. No.                         571.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/lichong/anaconda3/lib/python3.11/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
